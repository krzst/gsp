// %% [markdown]
// <div class="gsc-page-module-main-header">
//     <h1>Welcome To "JAVA Beginner Course"! <small> [ You are in good hands! ]</small></h1>
// </div>

// %% [markdown]
// ---

// %% [markdown]
// <div class="gsc-info-box gs-panel gs-panel-default">
//   <div class="gs-panel-heading">
//     <h4 class="gsc-panel-header-label"><span>INFO</span><span class="bi bi-info-square gsc-section-header-icon"></span>
//     </h4>
//   </div>
//   <div class="gs-panel-body">
//     <div class="gsc-info-text">
//       <div class="media gsc-media-block">
//         <table class="gsc-info-text">
//           <tr>
//             <td class="gsc-media-block-left">
//                   <video height="240" src="./video/000-intro.mp4" controls></video>
//             </td>
//             <td>
//               <div class="media-body gsc-info-text gsc-info-box">
//                 <h4 class="media-heading">Structure and navigation - how to use this course</h4>
//                   <p>Navigating through this course effectively is crucial for you to find the information you seek efficiently. Here's some key information about navigating and structure of this course. Each lesson may consist of the follwing sections: <i>INFO (you're reading it now), THEORY, CASE STUDY, PRACTICE</i> and <i>SUMMARY</i></p>
//               </p><strong><i class="bi bi-arrow-left"> Please watch the video to get all the details</i></strong>.</p>
//               </div>
//             </td>
//           </tr>
//         </table>
//       </div>
//     </div>
//     <div class="gs-panel gs-panel-danger gsc-general-info-box-panel">
//             <div class="gs-panel-heading gsc-general-info-panel-header">
//                 <span class="bi bi-lightning-charge gsc-section-header-icon"></span>
//             </div>
//             <div class="gs-panel-body gsc-general-info-panel-body">
//                 <div class="gsc-info-text gsc-general-info-box">
//                     <i>
//                         <strong>Almost zero configuration!</strong></i>
//                 </div>
//             </div>
//         </div>
//   </div>
// </div>

// %% [markdown]
// ---

// %% [markdown]
// <div class="gsc-info-box gs-panel gs-panel-success">
//     <div class="gs-panel-heading">
//         <h4 class="gsc-panel-header-label"><span>THEORY</span><span class="bi bi-book gsc-section-header-icon"></span>
//         </h4>
//     </div>
//     <div class="gs-panel-body">
//         <div class="gsc-info-text"><span class="glyphicon glyphicon-book" aria-hidden="true"></span>
//             <div class="gsc-list-section">
//                 <p>This section is dedicated to theory typically serves theoretical concepts and principles to a specific subject or field. Here's a detailed description of what this sestion can contain:</p>
//                 <ol>
//                     <li>
//                         <p><strong>Purpose and Overview:</strong></p>
//                         <ul>
//                             <li>Provides a comprehensive understanding of fundamental concepts and theoretical frameworks relevant to the subject matter.</li>
//                             <li>It serves as a valuable resources and deeper insights into the theoretical underpinnings of the topic.
//                             </li>
//                         </ul>
//                     </li>
//                     <li>
//                         <p><strong>Detailed Explanations:</strong></p>
//                         <ul>
//                             <li>Each theoretical concept is accompanied by a detailed explanation that
//                                 elucidates its meaning, significance, and applications.</li>
//                             <li>Complex topics may be broken down into digestible segments, with examples,
//                                 illustrations, and real-world analogies to aid understanding.</li>
//                         </ul>
//                     </li>
//                     <li>
//                         <p><strong>Visual Aids and Multimedia:</strong></p>
//                         <ul>
//                             <li>Visual aids such as diagrams, charts, graphs, and videos may be incorporated to enhance
//                                 comprehension and engagement.</li>
//                             <li>Multimedia elements help illustrate abstract concepts, facilitate visual learning, and
//                                 make the content more accessible to diverse audiences.</li>
//                         </ul>
//                     </li>
//                     <li>
//                         <p><strong>References and Further Reading:</strong></p>
//                         <ul>
//                             <li>Can provide references and recommended reading materials for those who wish to explore the topic in more depth.</li>
//                             <li>These resources may include textbooks, scholarly articles, research papers, and
//                                 reputable websites related to the subject matter.</li>
//                         </ul>
//                     </li>
//                 </ol>
//                 <p>Overall, the theory section serves as a valuable educational resource that empowers you to deepen
//                     your knowledge, broaden your perspectives, and gain a solid foundation in the theoretical aspects
//                     of the subject matter.</p>
//             </div>
//         </div>
//     </div>
// </div>

// %% [markdown]
// ---

// %% [markdown]
// <div class="gsc-info-box gs-panel gs-panel-info">
//     <div class="gs-panel-heading">
//         <h4 class="gsc-panel-header-label"><span>CASE STUDY</span><span
//                 class="bi bi-textarea-t gsc-section-header-icon"></span></h4>
//     </div>
//     <div class="gs-panel-body">
//         <div class="gsc-info-text">
//             <div class="gsc-info-text">
//     <p>This section provides real-world applications and scenarios to
//         illustrate key concepts and principles discussed throughout our website. Apart from that serves as a practical
//         resource for users seeking to understand how theoretical knowledge can be applied in various contexts:</p>
//     <ol>
//         <li>
//             <p><strong>Detailed Explanations</strong>: we offer detailed explanations of the examples and case studies
//                 presented. We highlight the relevance of each example to the overarching concept or principle being
//                 discussed, providing insights into its significance and impact.
//             </p>
//         </li>
//         <li>
//             <p><strong>Scenarios</strong>: that apply theoretical knowledge to solve problems including
//                 examples
//                 that demonstrate the practical implications of theory in action.</p>
//         </li>
//     </ol>
//     <p>"Case Study" section allowes you to discover collection of examples and case studies. Gain
//         practical insights and uncover innovative solutions to challenges in your own field of interest.</p>
//     <p><strong>Content markers</strong></p>
//     <p>
//         <strong class="gsc-difficult-topic gsc-tooltip">Difficult topic <span class="gsc-tooltiptext">Not required to continue</span><i class="bi bi-emoji-dizzy-fill"></i></strong> Some chapters will containt this marker. It indicates the topic can cause you some difficulties but don't worry. Usually we want to just mention about the topic but it's not crucial to continue the course.</p><p>On the other hand quite often you will encounter this marker <strong class="gsc-friendly-explanation gsc-tooltip">Friendly explanation <span class="gsc-tooltiptext">Hope it will help</span> <i class="bi bi-chat-heart-fill"></i></strong>. This is a very Friendly explanation <span class="gsc-tooltiptext">Hope it will help</span> of more abstract topics so you can see a reference to real world.</p>
//                 <p>When you see <strong class="gsc-extra-topic gsc-tooltip">Extra topic <i class="bi bi-lightbulb-fill"></i><span class="gsc-tooltiptext">Some more info</span></strong> it means there is something new that was not covered yet but will be later in this course. Something worth looking at closer.</p>
//             </div>
//         </div>
//     </div>
// </div>

// %% [markdown]
// ---

// %% [markdown]
// <div class="gsc-info-box gs-panel gs-panel-warning">
//     <div class="gs-panel-heading">
//         <h4 class="gsc-panel-header-label"><span>PRACTICE</span><span
//                 class="bi bi-pencil-square gsc-section-header-icon"></span>
//         </h4><span>Time to see in action what we've aleady learned.</span>
//     </div>
//     <div class="gs-panel-body">
//         <div class="gsc-info-text">
//             <p>This section is designed to provide hands-on training exercises, practice problems, and interactive
//                 simulations to help you enhance your knowledge and proficiency in various subjects:</p>
//             <ol>
//                 <li>
//                     <p><strong>Interactive Practice Exercises</strong>: put your knowledge to the test with interactive
//                         practice exercises that reinforce key concepts and allow you to apply what you've learned in a
//                         practical context. These exercises range from coding challenges and mathematical puzzles to
//                         writing prompts and language drills, providing opportunities for active learning and
//                         skill-building.
//                     </p>
//                 </li>
//                 <li>
//                     <p><strong>Detailed Explanations</strong>: each training exercise comes with detailed explanations,
//                         step-by-step instructions, and tips to guide you through the learning process.</p>
//                 </li>
//             </ol>
//             <p>Each excercise has its own:</p>
//             <ol>
//                 <li>
//                     <p><strong>Exercise number</strong>: marked by sign<span
//                             class="bi bi-gear-fill gsc-section-header-icon">.
//                     </p>
//                 </li>
//                 <li>
//                     <p><strong>Detailed Description</strong>: what needs to be done to accopmlish it.
//                     </p>
//                 </li>
//                 <li>
//                     <p><strong>Code editor</strong>: where you write your solution. It's a separated section just below
//                         description.
//                     </p>
//                     <p>In order to run your code follow this instruction:</p>
//             <div class="gs-panel gs-panel-warning gsc-readonly-language-box-panel">
//             <div class="gs-panel-heading gsc-how-to-run-panel-header">
//                 <span class="bi bi-lightning-charge gsc-section-header-icon"></span>
//             </div>
//             <div class="gs-panel-body gsc-how-to-run-panel-body">
//                 <div class="gsc-info-text gsc-how-to-run-box">
//                     <i>
//                         <strong>To run</strong>: click on the code section and press <span
//                             class="bi bi-play-fill"></span> icon from the top menu or
//                         <span class="gsc-key-shortcut">Win+Enter</span>&nbsp;&nbsp;for&nbsp;&nbsp;<img
//                             class="gsc-os-icon-small"
//                             src="./imgs/windows_icon.png" alt="Windows"/>&nbsp;&nbsp;or&nbsp;<span
//                             class="gsc-key-shortcut">Cmd+Return</span>&nbsp;for&nbsp;&nbsp;<img
//                             class="gsc-os-icon-small"
//                             src="./imgs/apple_icon.png" alt="Apple"/>&nbsp;</i>
//                 </div>
//             </div>
//         </div>
//             <p>
//                 When you run the code you will see the result just below the code seciton. It will looks like below:
//             </p>
//             <p>
//                 <div class="lm-Widget jp-RenderedText jp-mod-trusted jp-OutputArea-output"><pre>The sum of 5 and 7 is: 12
// </pre></div>
//             </p>
//                         <p>If you stuck or need inspiration you can always check one of possible solution by clicking this button (this one does nothing but when you face a real excercise it will <i class="bi bi-emoji-smile"></i> )</p>
//             <p>
//                 <a href="javascript:void(0)" target="_blank" rel="noopener noreferrer" class="gs-btn gs-btn-warning gsc-solution-link">Check solution&nbsp;&nbsp;<i class="bi bi-arrow-up-right-square"></i>
// </a>
//             </p>
//                 </li>
//             </ol>
//             </p>
//             <p><strong>Please try with the code below<span class="bi bi-arrow-down gsc-section-header-icon"></strong></p>
//         </div>
//     </div>
// </div>

// %% [markdown]
// <div class="gsc-info-box gs-panel gs-panel-warning">
//     <div class="gs-panel-heading">
//         <h5 class="gsc-panel-header-label"><span>MY EXERCISE 001 <span
//                     class="bi bi-gear-fill gsc-section-header-icon"></span></span></span></h5>
//     </div>
//     <div class="gs-panel-body">
//         <div class="panel panel-default">
//             <p class="gsc-info-text">
//                 Here you will find detailed description. You can even try to run it by following the instruction above <i class="bi bi-arrow-up"></i>
//             </p>
//         </div>
//     </div>
// </div>

// %%
// THIS IS CODE EDITOR FOR YOUR SOLUTION. YOU CAN TYPE HERE
int a = 1;

System.out.println(a);

// Command to execute to get the JDK version
        String command = "java -version";

        try {
            // Execute the command
            Process process = Runtime.getRuntime().exec(command);

            // Read the output of the command
            BufferedReader reader = new BufferedReader(new InputStreamReader(process.getErrorStream()));
            String line;
            while ((line = reader.readLine()) != null) {
                // Check if the line contains version information
                if (line.contains("version")) {
                    System.out.println("Installed JDK version: " + line.split(" ")[2].replace("\"", ""));
                    break;
                }
            }

            // Close the reader
            reader.close();

        } catch (IOException e) {
            System.out.println("An error occurred while checking JDK version: " + e.getMessage());
            e.printStackTrace();
        }
// Out:
// 1
// Installed JDK version: 17.0.10

// %% [markdown]
// ---

// %% [markdown]
// <div class="gsc-info-box gs-panel gs-panel-primary">
//     <div class="gs-panel-heading">
//         <h4 class="gsc-panel-header-label"><span>SUMMARY</span><span
//                 class="bi bi-card-list gsc-section-header-icon"></span></h4>
//     </div>
//     <div class="gs-panel-body gsc-info-text">
//         <p>Summary section, where you can find concise summaries and recaps of key information, insights, and takeaways from various topics covered in given lesson.</p>
//     </div>
// </div>

// %% [markdown]
// <div class="gsc-info-box gs-panel gs-panel-primary">
//     <div class="gs-panel-heading">
//         <div class="gsc-end-chapter-info">Great Job <span class="bi bi-rocket-takeoff gsc-section-header-icon"></span><br/><br/>Thank you and see you in the next lesson!</div>
//     </div>
// </div>
